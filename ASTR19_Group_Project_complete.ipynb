# %%
import numpy as np #vd
import matplotlib.pyplot as plt #vd
from tabulate import tabulate #vd
from scipy.optimize import curve_fit

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# HJD (Heliocentric Julian Date) double days null = x
x = np.array([
 2449676.0632, 2449767.77441, 2449768.83203, 2449793.79785, 2450056.98828,
 2450087.88184, 2450088.91894, 2450089.00586, 2450089.77637, 2450089.98633,
 2450090.74512, 2450090.89258, 2450091.84863, 2450091.96973, 2450120.87243,
 2450121.88866, 2450124.85765, 2450125.77783, 2450126.83752, 2450127.85104,
 2450128.86732, 2450144.71034, 2450144.85357, 2450145.625, 2450145.76465,
 2450148.88742, 2450150.74885, 2450152.66281, 2450168.74902, 2450171.73959,
 2450172.68686, 2450173.72485, 2450179.73422, 2450180.68848, 2450181.63379,
 2450186.73954, 2450187.68636, 2450199.68319, 2450200.70104, 2450201.68663,
 2450202.68868, 2450203.68772, 2450214.68668, 2450215.67357, 2450233.69028,
 2450422.00586, 2450437.92852, 2450441.9541, 2450502.78136, 2450503.76303,
 2450504.77366, 2450536.77162, 2450537.7645, 2450550.72661, 2450563.71983,
 2450614.69333, 2450793.90234, 2450794.96191, 2450831.93164, 2451153.0332,
 2451155.01856, 2451206.87793, 2451212.92549, 2451213.88293, 2451242.74023,
 2451298.72157, 2451305.70801, 2451469.05273, 2451532.99609, 2451535.00684,
 2451536.94922, 2451540.00781, 2451581.84883, 2451607.82779, 2451626.73438,
 2451629.80566, 2451840.04883, 2451842.03582, 2451860.05664, 2451861.03711,
 2451874.00586, 2451880.01946, 2451895.00493, 2451906.96312, 2451910.89618,
 2451913.96456, 2451914.9266, 2451927.90889, 2451969.78803, 2451971.80977,
 2451979.74933, 2452000.71484, 2452033.71044, 2452040.69009, 2452041.6994,
 2452217.04492, 2452257.03439, 2452262.98773, 2452267.96362, 2452278.93559,
 2452281.98047, 2452285.98783, 2452287.95594, 2452298.90856, 2452299.77417,
 2452306.80667, 2452315.80411, 2452316.85626, 2452333.81638, 2452334.73047,
 2452335.78936, 2452338.83203, 2452345.78535, 2452348.77603, 2452359.81445,
 2452360.69141, 2452375.73439, 2452380.69821, 2452388.68985, 2452408.71412,
 2452409.7121, 2452410.70428, 2452419.71506, 2452420.71259, 2452421.71169,
 2452422.72106, 2452426.73142, 2452427.69703, 2452428.70336, 2452429.70827,
 2452553.02973, 2452554.0277, 2452554.99206, 2452565.01999, 2452567.04981,
 2452575.04492, 2452576.04315, 2452576.98474, 2452585.01747, 2452595.01118,
 2452598.99109, 2452600.96715, 2452606.98584, 2452608.96373, 2452631.93493,
 2452656.94906, 2452705.75516, 2452722.74956, 2452723.75683, 2452737.69963,
 2452990.98926, 2452992.01973, 2453008.97305, 2453009.82291, 2453014.91699,
 2453018.88184, 2453020.90625, 2453021.88885, 2453034.84961, 2453068.80437,
 2453069.74609, 2453079.73859, 2453081.73731, 2453100.70337, 2453101.6739,
 2453102.72334, 2453108.70748, 2453119.68654, 2453282.03418, 2453283.02688,
 2453337.93066, 2453338.97882, 2453362.93359, 2453363.90318, 2453383.88228,
 2453384.88244, 2453385.86724, 2453386.84468, 2453387.87126, 2453388.83796,
 2453389.81824, 2453390.91379, 2453391.95825, 2453392.78225, 2453402.88127,
 2453403.89456, 2453404.86772, 2453405.87794, 2453436.73642, 2453437.78982,
 2453438.73703, 2453439.74637, 2453440.7431, 2453441.82095, 2453460.69637,
 2453475.6786, 2453476.68059, 2453477.68219, 2453478.68579, 2453479.67637,
 2453516.69655, 2453669.06331, 2453744.93382, 2453752.9071, 2453755.87845,
 2453756.84973, 2453773.7296, 2453773.81957, 2453773.96883, 2453774.80103,
 2454050.02388, 2454072.02159, 2454073.01428, 2454073.95856, 2454098.95179,
 2454100.01728, 2454101.97919, 2454102.84959, 2454103.00129, 2454103.8473,
 2454103.93224, 2454133.84118, 2454134.81738, 2454135.75896, 2454165.7782,
 2454166.70646, 2454167.67803, 2454168.80657, 2454169.84412, 2454196.73046,
 2454216.7786, 2454219.74126, 2454220.75738, 2454426.06351, 2454427.05271,
 2454428.0301, 2454429.04614, 2454449.932, 2454457.97956, 2454517.7817,
 2454547.8393, 2454574.71092, 2454578.74687, 2454598.70674, 2454725.03198,
 2454726.02537, 2454783.98942, 2454784.98892, 2454844.90482, 2454846.02038,
 2454846.95168, 2454847.89244, 2454848.88496, 2454849.83585, 2454863.84482,
 2454864.85968, 2454865.86258, 2455167.02476, 2455167.99733, 2455172.01593,
 2455228.79089, 2455312.67241, 2455546.93183, 2455554.96177, 2455576.88561,
 2455577.86121, 2455578.76532, 2455578.86419, 2455582.8289, 2455583.87264,
 2455584.86735, 2455585.89067, 2455602.8169, 2455603.80404
])

# Radial velocity = y
y = np.array([
    131.910003662, 22.6000003815, -5.48999977112, 107.309997559, 116.669998169,
    77.2600021362, 32.5999984741, 33.7299995422, 2.73000001907, 2.24000000954,
    -9.72999954224, -11.1199998856, -37.6500015259, -42.75, -18.4400005341,
    -20.9599990845, 27.3099994659, 47.2099990845, 79.0500030518, 100.86000061,
    109.730003357, 118.199996948, 110.160003662, 99.0800018311, 96.2300033569,
    17.0200004578, -14.3800001144, -8.21000003815, 19.2999992371, 87.8399963379,
    107.459999084, 103.370002747, -28.6399993896, -27.2000007629, -25.3299999237,
    121.800003052, 119.040000916, 86.4700012207, 112.790000916, 124.019996643,
    141.460006714, 132.990005493, 86.4199981689, 94.7200012207, 111.230003357,
    107.879997253, 104.599998474, -1.19000005722, -29.0900001526, -31.2999992371,
    -4.84999990463, 39.0400009155, 75.9300003052, 48.3800010681, -1.49000000954,
    76.9199981689, -22.8299999237, -32.7400016785, 94.5599975586, 54.8800010681,
    68.8899993896, -60.0499992371, 74.4700012207, 90.6699981689, 70.9300003052,
    39.9000015259, -0.980000019073, -71.1200027466, 32.6199989319, 66.0,
    62.0, -22.4099998474, 42.9399986267, 38.9199981689, 1.08000004292,
    -90.6500015259, -20.5, 29.0699996948, 16.8199996948, -16.2000007629,
    32.8100013733, -93.6900024414, -108.88999939, -72.5500030518, -100.25,
    -19.8600006104, -0.0799999982119, -22.4799995422, -69.3700027466,
    -18.3199996948, -44.0900001526, -55.0299987793, 33.8899993896,
    -104.940002441, -113.61000061, -123.480003357, -26.4300003052,
    -93.9400024414, 10.7600002289, -51.6899986267, 22.1399993896, 5.13000011444,
    -59.1699981689, 15.3240842819, -4.92000007629, -113.550003052, -26.3500003815,
    -52.9300003052, -107.099998474, -112.559997559, -102.730003357, -1.46000003815,
    -55.5600013733, -130.570007324, -46.6800003052, -60.9700012207, -60.0699996948,
    -87.5899963379, -33.4399986267, -109.230003357, -98.0699996948, -69.3300018311,
    -61.5900001526, -88.3000030518, -117.690002441, -109.199996948, -50.9000015259,
    -14.0500001907, 4.30999994278, 5.88999986649, -90.25, -99.3399963379,
    -106.989997864, -26.7399997711, -85.8799972534, 7.38999986649, 24.2199993134,
    18.5, -96.2099990845, -49.1599998474, -95.2600021362, -52.4700012207,
    21.9899997711, -33.4900016785, -5.25, -121.269996643, -13.8199996948,
    33.9599990845, 25.9200000763, 31.2800006866, -70.9800033569, -73.9499969482,
    -118.279998779, -109.370002747, 30.1900005341, -26.6100006104, -84.9499969482,
    -108.760002136, -35.6500015259, -73.3499984741, -63.1699981689, -56.4199981689,
    -93.2399978638, -15.8000001907, 2.8599998951, 21.2800006866, -78.2099990845,
    43.9799995422, -22.8799991608, -32.3899993896, 49.4700012207, 50.4700012207,
    -44.0699996948, -13.1400003433, 39.1199989319, 18.6200008392, -24.2399997711,
    -38.5099983215, -61.2400016785, -85.5299987793, -76.9100036621, -77.7300033569,
    -41.5600013733, -13.1700000763, -72.0299987793, -74.9499969482, -80.7900009155,
    -74.3300018311, -11.7100000381, 18.9799995422, 37.0099983215, 62.5699996948,
    72.5999984741, 52.8899993896, -70.4800033569, -63.1399993896, -71.5599975586,
    -73.4400024414, -73.4899978638, -41.1599998474, 3.36999988556, -64.4000015259,
    4.38000011444, -16.5599994659, -63.1800003052, -57.3400001526, -28.1800003052,
    -27.5100002289, -36.9500007629, -2.58999991417, -49.5999984741, 78.3700027466,
    46.3800010681, 30.7099990845, 93.6900024414, 103.849998474, 87.5299987793,
    76.9300003052, 62.3600006104, 31.0599994659, 23.7399997711, -6.0,
    -43.9599990845, -45.2099990845, -71.6600036621, -44.7599983215, -30.1000003815,
    -13.3800001144, 26.1900005341, -42.8100013733, 95.0500030518, 53.2999992371,
    33.4599990845, 46.9399986267, 0.569999992847, -29.0, -35.5999984741,
    93.37550354, -0.680000007153, -42.7099990845, -20.6100006104, -31.1299991608,
    5.63000011444, 131.690002441, 18.8299999237, 44.5200004578, 2.1400001049,
    37.9099998474, 75.5999984741, 113.400001526, 116.230003357, 111.209999084,
    104.809997559, 83.7200012207, 104.980003357, 72.0699996948, 48.5800018311,
    95.4499969482, 121.370002747, 95.6299972534, 112.830001831, 48.25,
    10.6499996185, -4.28000020981, 51.4900016785, 72.4700012207, 97.7200012207,
    102.930000305, 47.3699989319, 18.1700000763, -9.75, -45.7200012207,
    -41.4099998474, -17.9500007629
])

# Uncertainty = z
z = np.array([
    4.8400002, 2.5699999, 2.6800001, 1.52, 1.6199999, 2.1600001, 1.64,
    1.5599999, 1.61, 1.53, 1.41, 1.66, 1.54, 1.59, 2.2, 1.7299999,
    1.8599999, 2.0999999, 3.1199999, 2.02, 1.8599999, 1.52, 1.59,
    1.6999999, 1.6999999, 2.6400003, 1.8300002, 2.73, 4.5900002,
    2.4300001, 2.29, 1.9, 1.29, 1.4899999, 1.53, 2.5899999, 3.04,
    2.02, 2.1300001, 2.51, 1.7199999, 2.54, 2.1700001, 2.55, 2.9400001,
    1.58, 1.2999998, 1.5500001, 1.4899999, 1.29, 1.26, 2.49, 1.7500001,
    1.76, 2.4400001, 1.6800001, 1.5700002, 1.59, 1.7800001, 2.29, 2.28,
    2.0599999, 2.27, 2.28, 2.1099999, 2.02, 2.29, 3.3799999, 2.3, 2.5999997,
    1.9299999, 2.1700001, 2.2, 2.53, 2.3099999, 2.1500001, 2.73, 1.96,
    2.1500001, 2.0999999, 2.96, 2.6400003, 2.3, 2.04, 1.91, 1.45,
    1.53, 1.5700002, 2.7500002, 2.5799999, 2.52, 3.04, 1.37, 1.45,
    1.4299999, 3.2899997, 2.0599999, 1.9500002, 1.2400001, 2.47, 4.1199999,
    2.1500001, 2.8299999, 0.9502338, 1.1799999, 1.6800001, 1.38, 1.6,
    1.5099999, 2.1900001, 1.4299999, 4.71, 2.04, 1.9200001, 2.29,
    2.9000001, 2.05, 2.46, 1.5500001, 1.35, 2.0999999, 1.59, 1.6,
    1.38, 1.4299999, 1.77, 1.3100001, 1.9, 1.22, 1.2999998, 1.5700002,
    1.5, 1.6199999, 1.61, 2.53, 2.23, 1.53, 1.6299999, 1.28, 1.09,
    1.04, 0.84, 0.98, 1.1799999, 1.5, 1.1900001, 1.13, 1.42, 1.41,
    1.17, 1.7500001, 1.41, 1.2400001, 1.2999998, 1.47, 2.3099999,
    3.05, 2.5599999, 1.9500002, 1.53, 2.22, 1.61, 2.4000001, 1.7899998,
    1.4299999, 1.1, 1.26, 3.2499998, 1.6199999, 1.05, 2.3299999,
    1.33, 2.01, 2.01, 1.9800001, 1.87, 1.7800001, 1.27, 2.0799999,
    1.8599999, 1.48, 1.97, 1.9200001, 1.9, 2.1500001, 2.02, 1.64,
    1.6999999, 2.04, 1.87, 1.87, 1.7899998, 1.9, 1.48, 1.6299999,
    1.8300002, 1.6299999, 1.6899999, 1.65, 2.3, 1.87, 1.7800001,
    1.2400001, 1.17, 2.29, 2.25, 2.0999999, 2.25, 1.9299999, 2.01,
    1.1, 1.0, 1.2999998, 1.33, 1.3200002, 1.35, 1.36, 2.25, 1.97,
    1.9399999, 2.03, 2.21, 1.02, 1.27, 1.04, 3.8099997, 1.41, 1.4899999,
    1.37, 1.22, 1.7899998, 1.13, 1.17, 1.34, 0.8, 0.79, 0.79,
    0.7520534, 1.2, 1.15, 1.08, 0.78, 0.98, 1.85, 2.3199999, 1.23,
    2.0999999, 2.0899999, 1.1900001, 0.89, 0.9299999, 1.35, 1.0700001,
    0.9299999, 1.4, 1.48, 1.48, 1.64, 1.4899999, 1.8599999, 1.4899999,
    0.95, 1.02, 1.27, 1.2999998, 1.02, 1.88, 1.03, 1.01, 1.0599999,
    1.15, 1.8300002, 0.96, 1.09
])

# %% [markdown]
# Radial Velocity with Uncertainty vs Time

# %%
#plt.figure(facecolor='lightgray') #vd
#plt.plot(x,y,'r--',label='Time(Days)')
#plt.plot(x,z,label='Time(Days)')
#plt.xlabel('Time(Days)') #vd
#plt.ylabel('Radial Velocity') #vd
#plt.savefig('Local-Time-vs-RV.png', facecolor='lightgray') #vd
#plt.show()

plt.figure(facecolor='lightgray') #hj
plt.errorbar(x, y, yerr=z, fmt='+', ecolor='gray', capsize=5, markersize='3', label='Radial Velocity with Uncertanty') #HJ
plt.xlabel('Time(Days)')
plt.ylabel('Radial Velocity')
plt.legend()
plt.savefig('Local-Time-vs-RV-with-Uncertanty.pdf', facecolor='lightgray')
plt.show()

# %% [markdown]
# Uncertainty vs Time

# %%
#plt.figure(facecolor='lightgray') #vd
#plt.plot(x,z,label='Time(Days)')
#plt.xlabel('Time(Days)')
#plt.ylabel('Uncertainty')
#plt.show() #vd

# %% [markdown]
# Plotting Residuals vs Time

# %%
y = np.array(y) #vd
z = np.array(z)
residuals = y - z
plt.figure(facecolor='lightgray')
plt.plot(x, residuals, 'bo-', label='Residuals (Measured - Model)')
plt.axhline(0, color='black', linestyle='--')
plt.xlabel('Time (Days)')
plt.ylabel('Residuals')
plt.title('Residuals vs Time')
plt.legend()
plt.grid(True)
plt.show() #vd

# %% [markdown]
# Histogram of Residuals

# %%
plt.figure(facecolor='lightgray') #vd
bin_width = 10
bins = np.arange(min(residuals), max(residuals) + bin_width, bin_width)
plt.hist(residuals, bins=bins, color='blue', edgecolor='black')
plt.xlabel('Residual (RV)')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.grid(True)
plt.savefig('Residuals-Histogram.pdf', facecolor='lightgray')
plt.show() #vd

# %% [markdown]
# Computing Standard Deviation of Residuals

# %%
std_res = np.std(residuals) #vd
print(f"Standard Deviation of Residuals: {std_res:.3f}")
# Out:
# Standard Deviation of Residuals: 67.057

# %% [markdown]
# Comparing The std with the Experimental Error

# %%
def oscillatory_func(t, A1, f1, phi1, A2, f2, phi2, C):
  #  two sines function
    return (A1 * np.sin(2 * np.pi * f1 * t + phi1) +
            A2 * np.sin(2 * np.pi * f2 * t + phi2) + C)

# %%
params, covariance = curve_fit(oscillatory_func, x, y, )
print(params)
# Out:
# [ 2.29698008  0.99999995 -0.01982778  2.29762234  0.99999995 -0.01987767
#   4.11046149]
# <ipython-input-15-4b6edf686667>:1: OptimizeWarning: Covariance of the parameters could not be estimated
#   params, covariance = curve_fit(oscillatory_func, x, y, )

# %%
# plot the fitted oscillatory function
t_fit = np.linspace(min(x), max(x), 1000)
y_fit = oscillatory_func(t_fit, *params)
plt.figure(facecolor='lightgray')
plt.title('Fitted Oscillatory Function')
plt.plot(x, y, 'bo', label='Data')
plt.plot(t_fit, y_fit, 'r-', label='Fitted Curve')
plt.show()

# %% [markdown]
# Secondary Planet in RV Data

# %%
# One-planet model
def one_planet(t, A, P, t0, gamma):
    return A * np.cos(2 * np.pi * (t - t0) / P) + gamma

# Initial guesses: amplitudes, periods, phases, offset
p0_1p = [10,        #A1
      10000,         #P1
      245,       #t01
      1 ]   #gamma

# Fit one-planet model
# The first return value is the optimal parameters. Assign it to params_1p.
# Removed sigma=z and absolute_sigma=True from the curve_fit call for one_planet
params_1p, covariance_1p = curve_fit(one_planet, x, y, p0=p0_1p) # curve_fit returns params and covariance

# One-planet residuals
fit_rv = one_planet(x, *params_1p)
residuals = y - fit_rv
std_resid = np.std(residuals)


# Plot the raw data with error bars
plt.errorbar(x, y, yerr=z, fmt='o', color='blue', ecolor='lightgray', capsize=3, label='Radial Velocity Data with Uncertainty')

# Plot the fitted model
# The second argument to plot should be the x-data for the fitted curve (the same x as the data)
# The first argument should be the calculated radial velocities from the fitted model (fit_rv)
plt.plot(x, fit_rv, color='red', linestyle='-', linewidth=2, label='Fitted Oscillatory Model')


# Add labels and title
plt.xlabel('Heliocentric Julian Date (HJD)')
plt.ylabel('Radial Velocity (m/s)')
plt.title('Radial Velocity Variations with Fitted One Planet Model')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# Now, plot the residual histogram separately

# Calculate one-planet residuals
fit_rv = one_planet(x, *params_1p)
residuals = y - fit_rv
std_resid = np.std(residuals)

plt.figure(facecolor='lightgray')
plt.hist(residuals, bins='auto', color='lightgray', edgecolor='black')
plt.xlabel('Residuals [m/s]')
plt.ylabel('Frequency')
# This title includes std_resid_2p which is not defined yet. Let's use std_resid.
plt.title(f'One-Planet Residuals Histogram (σ = {std_resid:.2f} m/s)')
plt.tight_layout()
# The filename suggests a 2-planet histogram. Let's change it to reflect the 1-planet fit.
plt.savefig('55Cnc_1planet_residual_histogram.pdf')
plt.show() # Display the residual histogram here

print(f"One-planet residual std: {std_resid:.2f}")
# Out:
# One-planet residual std: 51.95

# %%
# Initial guesses: amplitudes, periods, phases, offset
p0 = [10,        #A1
      10000,         #P1
      245,       #t01
      200,         #A2
      200.0,       #P2
      200,      #t02
      1,     ]   #gamma

# Fit two-planet model
params_2p, _ = curve_fit(two_planets, x, y, sigma=z, absolute_sigma=True, p0=p0)



# Use the fitted parameters (params_2p) for plotting the two-planet model
y_model = two_planets(x_model, *params_2p)

plt.figure(figsize=(12, 7))

# Plot the raw data with error bars
plt.errorbar(x, y, yerr=z, fmt='o', color='blue', ecolor='lightgray', capsize=3, label='Radial Velocity Data with Uncertainty')

# Plot the fitted model
plt.plot(x_model, y_model, color='red', linestyle='-', linewidth=2, label='Fitted Oscillatory Model')

# Add labels and title
plt.xlabel('Heliocentric Julian Date (HJD)')
plt.ylabel('Radial Velocity (m/s)')
plt.title('Radial Velocity Variations with Fitted 2 Planet Model')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show() # Display the two-planet fit plot here

# Now, plot the residual histogram separately

# Calculate two-planet residuals
fit_rv_2p = two_planets(x, *params_2p)
residuals_2p = y - fit_rv_2p
std_resid_2p = np.std(residuals_2p)

plt.figure(facecolor='lightgray')
plt.hist(residuals_2p, bins='auto', color='lightgray', edgecolor='black')
plt.xlabel('Residuals [m/s]')
plt.ylabel('Frequency')
plt.title(f'Two-Planet Residuals Histogram (σ = {std_resid_2p:.2f} m/s)')
plt.tight_layout()
plt.savefig('55Cnc_2planet_residual_histogram.pdf')
plt.show() # Display the residual histogram here

print(f"Two-planet residual std: {std_resid_2p:.2f}, One-planet residual std: {std_resid:.2f}")
# Out:
# Two-planet residual std: 51.43, One-planet residual std: 51.95

# %%
# Step 5: Fit a second sinusoidal model to the residuals

# Define model for residuals: another sine wave
def second_planet_model(t, K2, P2, phi2, offset2):
    return K2 * np.sin(2 * np.pi * t / P2 + phi2) + offset2

# Initial guess for second planet's parameters
initial_guess2 = [20, 50, 0, 0]


import pandas as pd
df = pd.DataFrame({
    "HJD": x,
    "Radial_Velocity": y,
    "Uncertainty": z
})


# Fit the model to residuals
params2, covariance2 = curve_fit(second_planet_model, df["HJD"], residuals_2p,
                                 sigma=df["Uncertainty"], absolute_sigma=True,
                                 p0=initial_guess2)

# Calculate the fitted second planet model evaluated at the original x data points
fitted_second_planet_values = second_planet_model(df["HJD"], *params2)


combined_model = fit_rv_2p + fitted_second_planet_values


# Compute new residuals
residuals2 = df["Radial_Velocity"] - combined_model
residual_std2 = np.std(residuals2)

plt.figure(figsize=(10, 6))
plt.hist(residuals2, bins='auto', alpha=0.7, color='gray', edgecolor='black')
plt.axvline(0, color='k', linestyle='dashed', linewidth=1)
plt.axvline(residual_std2, color='r', linestyle='dashed', linewidth=1, label=f'+1σ = {residual_std2:.2f}')
plt.axvline(-residual_std2, color='r', linestyle='dashed', linewidth=1, label=f'-1σ = {residual_std2:.2f}')
plt.xlabel("Residuals after 2-planet fit + residual fit (m/s)")
plt.ylabel("Frequency")
plt.title("Histogram of Residuals After Fitting a Model to 2-Planet Residuals")
plt.legend()
plt.tight_layout()
plt.savefig("second_planet_histogram.pdf")

print(params2, residual_std2)
# Out:
# [-2.00154080e+01  5.05591033e+01  3.40853077e+03  1.41895755e+00] 50.57860935696582

# %%
# Step 6

K = params[0]        # Amplitude (A1) from two-planet fit (in m/s)
P = params[1]        # Period (P1) from two-planet fit (in days)
M_star = 0.91

# Compute mass of exoplanet in Jupiter masses
M_exoplanet = (K / 28.4) * (P / 365)**(1/3) * (M_star)**(2/3)

print(f"Exoplanet Mass = {M_exoplanet:.3f} M_Jup")
# Out:
# Exoplanet Mass = 0.011 M_Jup
